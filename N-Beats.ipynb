# %%
import pandas as pd
import numpy as np
from pandas_datareader.data import DataReader
import yfinance as yf
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
yf.pdr_override()
from datetime import datetime
import copy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from darts.models import NBEATSModel
# Out:
# WARNING:tensorflow:From c:\Users\baljyot\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def stock_data(stock_name, duration, company_name):#duration in years
   
    end_time = datetime.now()
    start_time = datetime(datetime.now().year - duration, datetime.now().month, datetime.now().day)  #using data of exactly duration year before
    stock=yf.download(stock_name,start_time,end_time)
    # stock["comany_name"]=company_name
    return stock
def plot(df, company):
    plt.figure(figsize=(10, 6))
    plt.plot(df.index, df['Adj Close'], color='blue', label='Adjusted Close')
    plt.title(f'Adjusted Close Prices for {company} Inc.')
    plt.xlabel('Date')
    plt.ylabel('Adjusted Close Price')
    plt.legend()  
    plt.grid(True)
    plt.show()

# %%
apple_stocks=stock_data('AAPL',4,'Apple')
plot(apple_stocks,'Apple')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
model = NBEATSModel(
    input_chunk_length=6,
    output_chunk_length=6,
    n_epochs=5,
    activation='LeakyReLU'
)

# %%
model.fit(apple_stocks['Close'].values )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.fit(apple_stocks['Close'].values )
#
# File c:\Users\baljyot\AppData\Local\Programs\Python\Python311\Lib\site-packages\darts\utils\torch.py:103, in random_method.<locals>.decorator(self, *args, **kwargs)
#     101 with fork_rng():
#     102     manual_seed(self._random_instance.randint(0, high=MAX_TORCH_SEED_VALUE))
# --> 103     return decorated(self, *args, **kwargs)
#
# File c:\Users\baljyot\AppData\Local\Programs\Python\Python311\Lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:732, in TorchForecastingModel.fit(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, trainer, verbose, epochs, max_samples_per_ts, num_loader_workers)
#     650 @random_method
#     651 def fit(
#     652     self,
#    (...)
#     663     num_loader_workers: int = 0,
#     664 ) -> "TorchForecastingModel":
#     665     """Fit/train the model on one or multiple series.
#     666
#     667     This method wraps around :func:`fit_from_dataset()`, constructing a default training
#    (...)
#     726         Fitted model.
#     727     """
#     728     (
#     729         series,
#     730         past_covariates,
#     731         future_covariates,
# --> 732     ), params = self._setup_for_fit_from_dataset(
#     733         series=series,
#     734         past_covariates=past_covariates,
#     735         future_covariates=future_covariates,
#     736         val_series=val_series,
#     737         val_past_covariates=val_past_covariates,
#     738         val_future_covariates=val_future_covariates,
#     739         trainer=trainer,
#     740         verbose=verbose,
#     741         epochs=epochs,
#     742         max_samples_per_ts=max_samples_per_ts,
#     743         num_loader_workers=num_loader_workers,
#     744     )
#     745     # call super fit only if user is actually fitting the model
#     746     super().fit(
#     747         series=seq2series(series),
#     748         past_covariates=seq2series(past_covariates),
#     749         future_covariates=seq2series(future_covariates),
#     750     )
#
# File c:\Users\baljyot\AppData\Local\Programs\Python\Python311\Lib\site-packages\darts\models\forecasting\torch_forecasting_model.py:785, in TorchForecastingModel._setup_for_fit_from_dataset(self, series, past_covariates, future_covariates, val_series, val_past_covariates, val_future_covariates, trainer, verbose, epochs, max_samples_per_ts, num_loader_workers)
#     781 """This method acts on `TimeSeries` inputs. It performs sanity checks, and sets up / returns the datasets and
#     782 additional inputs required for training the model with `fit_from_dataset()`.
#     783 """
#     784 # guarantee that all inputs are either list of `TimeSeries` or `None`
# --> 785 series = series2seq(series)
#     786 past_covariates = series2seq(past_covariates)
#     787 future_covariates = series2seq(future_covariates)
#
# File c:\Users\baljyot\AppData\Local\Programs\Python\Python311\Lib\site-packages\darts\utils\ts_utils.py:102, in series2seq(ts, seq_type_out, nested)
#      94 if not isinstance(seq_type_out, SeriesType):
#      95     raise_log(
#      96         ValueError(
#      97             f"Invalid parameter `seq_type_out={seq_type_out}`. Must be one of `(0, 1, 2)`"
#      98         ),
#      99         logger=logger,
#     100     )
# --> 102 seq_type_in = get_series_seq_type(ts)
#     104 if seq_type_out == seq_type_in:
#     105     return ts
#
# File c:\Users\baljyot\AppData\Local\Programs\Python\Python311\Lib\site-packages\darts\utils\ts_utils.py:221, in get_series_seq_type(ts)
#     219 elif isinstance(ts[0], TimeSeries):
#     220     return SeriesType.SEQ
# --> 221 elif isinstance(ts[0][0], TimeSeries):
#     222     return SeriesType.SEQ_SEQ
#     223 else:
#
# IndexError: invalid index to scalar variable.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
